# %%
from icrawler.builtin import BaiduImageCrawler

crawler = BaiduImageCrawler(
    storage={'root_dir': 'dataset/kitty'}
)

crawler.crawl(
    keyword='고양이',
    max_num=50
)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_23352\3348409654.py:3: ResourceWarning: unclosed <ssl.SSLSocket fd=1592, family=2, type=1, proto=0, laddr=('172.16.100.53', 49702), raddr=('142.251.118.99', 443)>
#   crawler = BaiduImageCrawler(
# ...
# 2026-03-16 14:59:48,771 - INFO - icrawler.crawler - start crawling...
# 2026-03-16 14:59:48,772 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2026-03-16 14:59:48,773 - INFO - feeder - thread feeder-001 exit
# 2026-03-16 14:59:48,774 - INFO - icrawler.crawler - starting 1 parser threads...
# 2026-03-16 14:59:48,775 - INFO - icrawler.crawler - starting 1 downloader threads...
# 2026-03-16 14:59:50,156 - INFO - parser - parsing result page http://image.baidu.com/search/acjson?tn=resultjson_com&ipn=rj&word=고양이&pn=0&rn=30
# 2026-03-16 14:59:50,172 - INFO - downloader - skip downloading file 000001.jpg
# 2026-03-16 14:59:50,176 - INFO - downloader - skip downloading file 000002.jpg
# ...
