# %% [markdown]
# # 1. root 테스트

# %%
import requests 

fastapi_url = "http://localhost:8080"

response = requests.get(fastapi_url)
print(response.status_code)
# Out:
# 200

# %%
print(response.json())
# Out:
# {'message': 'Hello World'}

# %% [markdown]
# # 2. upload_image 테스트

# %%
upload_image_url = f"{fastapi_url}/upload_image"
print(upload_image_url)
# Out:
# http://localhost:8080/upload_image

# %%
# 이미지 가져오기
with open("./sit.jpg", "rb") as f:
    # f는 이미지를 바이너리 형태로 불러오는 것이다.
    files = {
        "file": f
    }

    response = requests.post(
        url=upload_image_url,
        files=files
    )
    if response.status_code == 200:
        print(response.json())
# Out:
# {'message': '이미지를 저장했습니다.', 'filename': './images/20260320075218-sit.jpg', 'time': '20260320075218'}

# %%
# 만약 Streamlit에서 file_uploader로 이미지를 받은 상태라면?
# uploaded_file = st.file_uploader(....)
# uploaded_file.name : 파일 이름
# uploaded_file.getvalue() : 위에서 f와 동일
# uploaded_file.type : 파일 타입(png, jpg, ....)

# files = {
#     "file": (
#         uploaded_file.getvalue()
#     )
# }

# %%
# 오늘의 과제:
# - request_test.ipynb 파일에 object detection 모델 예측 요청하기 (/detect_image)
# - (도전) streamlit에 object detection url 요청 반영해보기
# - (대체) file_uploader로 받은 변수 이름을 uploaded_file 이라고 하자. 다음을 출력해주세요.
# -        print(uploaded_file.name)
# -        print(uploaded_file.type)

# %% [markdown]
# # 3. object_detection 테스트

# %%
# /object_detection 엔드포인트 URL 설정
object_detection_url = f"{fastapi_url}/object_detection"
print(object_detection_url)
# Out:
# http://localhost:8080/object_detection

# %%
import requests

# 이미지 파일을 바이너리로 열어 서버로 전송
with open("./sit.jpg", "rb") as f:
    files = {"file": f}  # 서버의 UploadFile 파라미터 이름과 동일하게 "file"로 설정

    response = requests.post(
        url=object_detection_url,
        files=files
    )

if response.status_code == 200:
    result = response.json()
    print(f"저장 파일명: {result['filename']}")
    print(f"탐지된 객체 수: {len(result['detections'])}개")
    print()

    # 탐지된 각 객체 정보 출력
    for i, det in enumerate(result["detections"]):
        print(f"[{i+1}번 객체]")
        print(f"  라벨     : {det['label']}")
        print(f"  신뢰도   : {det['confidence']:.2%}")  # 소수 → 퍼센트
        print(f"  박스좌표 : {[round(v, 1) for v in det['box']]}")  # 소수점 1자리로 표시
else:
    print(f"에러 발생: {response.status_code}")
# Out:
# 저장 파일명: ./images/20260320075218-sit.jpg
# 탐지된 객체 수: 1개
#
# [1번 객체]
#   라벨     : person
#   신뢰도   : 82.40%
#   박스좌표 : [1305.9, 1690.3, 2197.7, 3915.6]

# %% [markdown]
# # 4. segmentation 테스트

# %%
import requests

# /segmentation 엔드포인트 URL 설정
segmentation_url = f"{fastapi_url}/segmentation"
print(segmentation_url)

# 이미지 파일을 바이너리로 열어 서버로 전송
with open("./sit.jpg", "rb") as f:
    files = {"file": f}

    response = requests.post(
        url=segmentation_url,
        files=files
    )

if response.status_code == 200:
    result = response.json()
    print(f"저장 파일명: {result['filename']}")
    print(f"탐지된 객체 수: {len(result['detections'])}개")
    print()

    # 탐지된 각 객체 정보 출력 (마스크 문자열은 너무 길어서 앞 30자만 표시)
    for i, det in enumerate(result["detections"]):
        print(f"[{i+1}번 객체]")
        print(f"  라벨     : {det['label']}")
        print(f"  신뢰도   : {det['confidence']:.2%}")
        print(f"  박스좌표 : {[round(v, 1) for v in det['box']]}")
        if det["mask"]:
            print(f"  마스크   : {det['mask'][:30]}... (base64 문자열)")  # 앞 30자만 미리보기
        else:
            print(f"  마스크   : None")
else:
    print(f"에러 발생: {response.status_code}")
# Out:
# http://localhost:8080/segmentation
# 저장 파일명: ./images/20260320075219-sit.jpg
# 탐지된 객체 수: 1개
#
# [1번 객체]
#   라벨     : person
#   신뢰도   : 72.11%
#   박스좌표 : [1223.8, 1693.7, 2201.6, 3754.8]
#   마스크   : iVBORw0KGgoAAAANSUhEUgAAAgAAAA... (base64 문자열)

# %%
import base64
import io
from PIL import Image
import matplotlib.pyplot as plt

# 서버에서 받은 base64 마스크를 이미지로 복원해서 시각화
detections = result["detections"]

# 마스크가 있는 객체만 필터링
mask_detections = [det for det in detections if det["mask"] is not None]
print(f"마스크가 있는 객체 수: {len(mask_detections)}개")

if mask_detections:
    fig, axes = plt.subplots(1, len(mask_detections), figsize=(5 * len(mask_detections), 5))

    # 객체가 1개일 때 axes가 리스트가 아니므로 리스트로 변환
    if len(mask_detections) == 1:
        axes = [axes]

    for ax, det in zip(axes, mask_detections):
        # base64 문자열 → 바이너리 → PIL Image로 복원
        mask_bytes = base64.b64decode(det["mask"])  # base64 디코딩 → PNG 바이너리
        mask_img = Image.open(io.BytesIO(mask_bytes))  # PNG 바이너리 → PIL Image

        ax.imshow(mask_img, cmap="gray")  # 흑백으로 표시 (0=배경, 255=객체)
        ax.set_title(f"{det['label']} ({det['confidence']:.0%})")
        ax.axis("off")

    plt.tight_layout()
    plt.show()
# Out:
# 마스크가 있는 객체 수: 1개

# %% [markdown]
# # 5. clip 테스트

# %%
import requests

# /clip 엔드포인트 URL 설정
clip_url = f"{fastapi_url}/clip"
print(clip_url)

# 이미지 파일을 바이너리로 열어 서버로 전송
with open("./sit.jpg", "rb") as f:
    files = {"file": f}

    response = requests.post(
        url=clip_url,
        files=files
    )

if response.status_code == 200:
    result = response.json()

    print(f"예측 결과: {result['predicted']}")  # 가장 유사도 높은 카테고리
    print()

    # 각 카테고리별 유사도 출력 (내림차순 정렬)
    print("=== 카테고리별 유사도 ===")
    sorted_sim = sorted(result["similarities"].items(), key=lambda x: x[1], reverse=True)
    for label, prob in sorted_sim:
        print(f"  {label:5s}: {prob:.1%}")
else:
    print(f"에러 발생: {response.status_code}")
# Out:
# http://localhost:8080/clip
# 예측 결과: 개
#
# === 카테고리별 유사도 ===
#   개    : 57.5%
#   돼지   : 41.8%
#   고양이  : 0.7%

# %% [markdown]
# # 6. 챗봇 테스트

# %%
import requests

chat_url = "http://localhost:8080/chat"

data = {"message": "안녕하세요?"}

response = requests.post(url=chat_url, json=data)
if response.status_code == 200:
    print(response.json())
# Out:
# {'text': '안녕하세요! 반갑습니다. 무엇을 도와드릴까요?\n\n다양한 주제로 도와드릴 수 있어요.\n- 간단한 질문에 답하기\n- 글쓰기 다듬기나 아이디어 뽑기\n- 번역이나 요약\n- 코딩 문제 해결 및 예제 코드 제시\n- 공부 계획, 일정 관리, 생활 팁 등\n\n원하시는 주제나 구체적인 요청을 알려주시면 바로 도와드리겠습니다!'}
