# %%
from dotenv import load_dotenv
import os
from openai import OpenAI

load_dotenv("../.env")

client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

response = client.responses.create(
    model="gpt-5.4", input="챗봇 만드는 거 어떻게 해야함?"
)

print(response.output[0].content[0].text)
# Out:
# 챗봇 만드는 방법은 **목표에 따라 크게 3가지**예요.
#
# ## 1. 제일 쉬운 방법: 기존 플랫폼 사용
# 코딩 없이 빠르게 만들고 싶으면:
# - **카카오 i 오픈빌더**
# - **Dialogflow**
# - **Chatfuel / ManyChat**
# - **OpenAI API + 노코드 툴** 조합
#
# 이런 걸 쓰면:
# - 질문/답변 시나리오 설정
# - 버튼형 메뉴
# - FAQ 챗봇
# - 고객센터용 챗봇
# 같은 걸 빠르게 만들 수 있어요.
#
# ---
#
# ## 2. AI 챗봇 만들기: LLM API 사용
# 사람처럼 자연스럽게 답하는 챗봇을 원하면 보통 이렇게 만듭니다.
#
# ### 기본 구조
# 1. **사용자 입력 받기**
# 2. **서버에서 AI API 호출**
# 3. **응답 받아서 화면에 출력**
#
# 예를 들면:
# - 프론트엔드: 웹/앱/카카오톡/디스코드
# - 백엔드: Python, Node.js
# - AI: OpenAI API 같은 LLM
# - 저장소: 대화 기록, 사용자 정보 DB
#
# ### 아주 간단한 흐름
# ```python
# from openai import OpenAI
#
# client = OpenAI(api_key="YOUR_API_KEY")
#
# response = client.responses.create(
#     model="gpt-4.1-mini",
#     input="안녕! 자기소개 해줘"
# )
#
# print(response.output_text)
# ```
#
# 이걸 서버에 붙이면 챗봇이 됩니다.
#
# ---
#
# ## 3. 직접 개발하는 방법
# 개발적으로 만들려면 보통 이런 순서예요.
#
# ### 1) 목적 정하기
# 먼저 정해야 함:
# - 고객센터 챗봇?
# - 쇼핑 추천 챗봇?
# - 사내 문서 검색 챗봇?
# - 캐릭터 챗봇?
#
# 목적에 따라 설계가 완전히 달라져요.
#
# ---
#
# ### 2) 답변 방식 정하기
# #### A. 규칙형 챗봇
# - 정해진 질문에 정해진 답
# - 빠르고 저렴함
# - 유연성은 낮음
#
# 예:
# - “영업시간 알려줘”
# - “환불 규정 알려줘”
#
# #### B. AI 챗봇
# - 자연어 이해
# - 문맥 유지 가능
# - 더 유연함
# - 비용/안전성 관리 필요
#
# ---
#
# ### 3) 기술 스택 고르기
# 초보면 보통:
# - **백엔드**: Python(FastAPI, Flask) 또는 Node.js(Express)
# - **프론트엔드**: React / Next.js
# - **DB**: PostgreSQL, MongoDB
# - **배포**: Vercel, Render, AWS
#
# ---
#
# ### 4) 핵심 기능 만들기
# 보통 챗봇에는 이런 게 들어가요:
# - 대화 입력창
# - 이전 대화 기억
# - 사용자 인증
# - 답변 생성
# - 로그 저장
# - 욕설/위험한 질문 필터링
# - 관리자 페이지
#
# ---
#
# ### 5) 문서 기반 챗봇이면 RAG 추가
# 회사 문서나 PDF 기반으로 답변하게 하려면:
# 1. 문서를 잘게 나눔
# 2. 임베딩 생성
# 3. 벡터DB에 저장
# 4. 사용자 질문과 관련 문서 검색
# 5. 검색된 문서를 AI에 같이 넣어 답변 생성
#
# 사용 도구 예:
# - FAISS
# - Pinecone
# - Weaviate
# - Chroma
#
# ---
#
# ## 초보자용 추천 개발 순서
# 제일 현실적인 입문 루트는 이거예요:
#
# ### 방법 A: 웹 챗봇
# 1. 간단한 HTML/JS 채팅창 만들기
# 2. Python FastAPI 서버 만들기
# 3. OpenAI API 연결
# 4. 대화 저장 기능 추가
# 5. 배포
#
# ### 방법 B: 카카오톡 챗봇
# 1. 카카오 오픈빌더 또는 챗봇 API 사용
# 2. 서버 만들기
# 3. 메시지 들어오면 AI API 호출
# 4. 답변 반환
#
# ---
#
# ## 예시 아키텍처
# ```text
# 사용자
#   ↓
# 웹사이트 / 카카오톡 / 디스코드
#   ↓
# 백엔드 서버 (Python/Node.js)
#   ↓
# OpenAI API
#   ↓
# DB(대화기록), 벡터DB(문서검색)
# ```
#
# ---
#
# ## 만들 때 주의할 점
# - **비용 관리**: API 호출 많으면 돈 꽤 듦
# - **개인정보**: 대화 저장 시 보안 필요
# - **환각 문제**: AI가 틀린 말 할 수 있음
# - **프롬프트 설계** 중요
# - **사용 제한/안전장치** 필요
#
# ---
#
# ## 진짜 최소한으로 시작하려면
# ### 필요한 것
# - OpenAI API 키
# - Python 또는 Node.js
# - 간단한 서버
# - 채팅 UI
#
# ---
#
# ## 내가 추천하는 시작법
# ### 코딩 가능하면
# - **Python + FastAPI + OpenAI API + 간단한 웹 UI**
#
# ### 코딩 거의 못하면
# - **노코드 챗봇 플랫폼** 먼저 사용
#
# ---
#
# ## 원하면 내가 바로 해줄 수 있는 것
# 1. **초보자용 챗봇 제작 로드맵**
# 2. **Python으로 만드는 예제 코드**
# 3. **웹 챗봇 전체 샘플**
# 4. **카카오톡 챗봇 만드는 방법**
# 5. **회사 문서 기반 AI 챗봇(RAG) 만드는 방법**
#
# 원하면 다음 중 하나로 바로 이어서 설명해줄게:
# - **“코딩 없이 만드는 법”**
# - **“파이썬으로 챗봇 만드는 예제”**
# - **“웹사이트 챗봇 전체 코드”**
# - **“카카오톡 챗봇 만드는 법”**

# %%
response = client.responses.create(
    model="gpt-5.4", input="챗봇 만드는 거 어떻게 해야함?"
)
