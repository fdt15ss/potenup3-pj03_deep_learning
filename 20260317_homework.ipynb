# %%
import requests

url = "http://localhost:8080/detect_image"

files = {
    "file": open(r"C:\potenup3\pj03_deep_learning\DogCatProject-1\test\images\000011_jpg.rf.91d33fd76f68a45b72facde88f941bb2.jpg", "rb")
}

response = requests.post(url, files=files)

response.json()
# Out:
# {'message': '이미지를 저장했습니다.',
#  'filename': './images/20260317161353-000011_jpg.rf.91d33fd76f68a45b72facde88f941bb2.jpg',
#  'time': '20260317161353',
#  'object_detection': [{'box': [198.97769165039062,
#     86.06456756591797,
#     510.2449645996094,
#     511.58380126953125],
#    'confidence': {},
#    'label': 'cat'}]}
